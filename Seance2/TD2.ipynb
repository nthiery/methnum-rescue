# %% [markdown]
# Merci de **ne pas modifier** le nom de ce notebook (même pour y inclure son nom).
#
# Quelques conseils:
# - pour exécutez une cellule, cliquez sur le bouton *Exécuter* ci-dessus ou tapez **Shift+Enter**
# - si l'exécution d'une cellule prend trop de temps, sélectionner dans le menu ci-dessus *Noyau/Interrompre*
# - en cas de très gros plantage *Noyau/Redémarrer*
# - **sauvegardez régulièrement vos réponses** en cliquant sur l'icone disquette ci-dessus à gauche, ou *Fichier/Créer une nouvelle sauvegarde*
#
# ----------------------------------------------------------------------------

# %% [markdown]
# # TP 2 : Listes
#
# On trouvera sur ce [lien](plots/Fiche_rappels_Seance02.pdf) un document pdf rappelant quelques notions essentielles à retenir pour les séances 1 et 2.
#
# Il est impératif de savoir faire les exercices marqués d'une étoile $(\star)$. Les exercices marqués de trois étoiles $(\star\!\star\!\star)$ nécessitent plus d'approfondissements. Ils ne sont pas prioritaires et pourront être résolus chez soi.

# %% [markdown]
# ## **Exercice 1 $(\star)$ :** Manipulations élémentaires de listes
# Définir la liste `[17, 38, 10, 25, 72]` et lui affecter un nom de variable.
#
# Ensuite, effectuer les actions suivantes :
# 1. trier et afficher la liste ;
# 2. ajouter l’élément 12 à la liste et afficher la liste ;
# 3. renverser son ordre en utilisant `.reverse()` et affichez la liste. On notera que la liste est modifiée ;
# 4. afficher l’indice de l’élément 17 ;
# 5. supprimer l’élément 38 et affichez la liste.
#
# On va maintenant utiliser la notion de slicing.
#
# 6. afficher la liste allant du 2<sup>e</sup> au 3<sup>e</sup> élément ;
# 7. afficher la liste allant du début au 4<sup>e</sup> élément ;
# 8. afficher la liste allant du 3<sup>e</sup> élément à la fin de la liste ;
# 9. afficher le dernier élément en utilisant une indexation négative ;
# 10. afficher la liste dans l'ordre inverse, sans qu'elle soit modifiée ;
# 11. afficher le plus grand et le plus petit élément de la liste.

# %%
#LA REPONSE ICI

# %% [markdown]
# ## **Exercice 2 $(\star)$ :** L'itérable `range()`
# Utilisez la fonction `range()` pour afficher :
# 1. les entiers de 0 à 3 ;
# 2. les entiers de 4 à 7 ;
# 3. les entiers pairs de 2 à 8.

# %%
#LA REPONSE ICI

# %% [markdown]
# ## **Exercice 3a $(\star\star)$ :** Rappels du cours sur la boucle `for`
#
# Nous avons parlé dans le cours de la boucle `for`, qui est très pratique pour parcourir une liste.
#
# 1. Pour commencer, recopiez cette boucle `for` dans la cellule du notebook ci-dessous et exécutez-la :
# ```python
# collection = range(10)
# for element in collection:
#     print(element)
# ```
# On observe que chaque élément de la collection `range(10)` a été affiché par Python, alors que nous n'avons eu besoin d'écrire la fonction `print` qu'une seule fois. La boucle `for` simplifie donc le code en répétant un bloc d'instructions pour chaque élément d'une collection qu'on lui fournit.
#
# La fonction `enumerate()` permet de créer une collection dans laquelle on a à la fois l'indice et l'élément correspondant d'une liste.
#
# 2. Créez une liste `[91,38,'a',29,'ks']` et affichez tous ses éléments et leur indice associé.
#
# Une boucle `for` pourra aussi être utilisée dans la création d'une liste en compréhension.
#
# 3. Créez une liste en compréhension contenant les entiers de `0` à `8`.
#
# **Indication :** on pourra s'aider de la fonction `range()` comme collection d'une boucle `for`.

# %%
#LA REPONSE ICI

# %% [markdown]
# ## **Exercice 3b $(\star\star)$ :** Liste de listes
#
# 1. Définissez une liste qui représente le tableau suivant :
# <table>
#   <tr>
#     <td>123</td>
#     <td>A<br></td>
#     <td>34</td>
#   </tr>
#   <tr>
#     <td>12</td>
#     <td>56</td>
#     <td>56</td>
#   </tr>
#   <tr>
#     <td>134</td>
#     <td>B</td>
#     <td>3+2j</td>
#   </tr>
# </table>
#
# 2. Affichez les éléments de la première ligne.
#
# 3. Affichez la liste des éléments de la dernière colonne, soit en utilisant une boucle 'for' simple, soit une liste en compréhension.

# %%
#LA REPONSE ICI

# %% [markdown]
# ## **Exercice 4 $(\star)$ :** Permutation d'éléments d'une liste
# Écrire un programme qui
# - déclare une liste d'entiers de 0 à 9
# - permute les élements d'indice 2 et 4 de cette liste.

# %%
#LA REPONSE ICI

# %% [markdown]
# ## **Exercice 5 $(\star)$ :** Tri dans une liste
# Écrire un programme qui fusionne deux listes quelconques de nombres **réels** et trie la liste résultante par ordre décroissant.

# %%
#LA REPONSE ICI

# %% [markdown]
# ## **Exercice 6 $(\star\star)$ :** *shallow copy* versus *deep copy*
# Dans la cellule du notebook ci-dessous, recopiez et comparez les deux séquences suivantes. Qu'est-ce que vous pouvez en conclure?
# ```python
# AA = list(range(10))
# BB = AA
# AA[1]=-8
# print('Liste AA :\n', AA)
# print('Liste BB :\n', BB)
# ```
# ```python
# AA = list(range(10))
# BB = AA[:]
# AA[1]=-8
# print('Liste AA :\n', AA)
# print('Liste BB :\n', BB)
# ```

# %%
#LA REPONSE ICI

# %% [markdown]
# ## **Exercice 7 $(\star)$ :** Liste en compréhension (encore)
#
# Quel est le résultat de la séquence suivante ?
# ```python
# lst = []
# for i in range(1,10):
#    lst.append(i**2)
# ```
# Utilisez une liste en compréhension pour obtenir un résultat équivalent, puis ajouter les commandes :
# 1. pour n'afficher que les 3 premiers éléments de la liste.
# 2. pour n'afficher que les 3 derniers éléments de la liste.
# 3. pour n'afficher que les éléments d'indice pair de la liste.
#
# $(\star\star)$ Toutes les réponses doivent être obtenues en une seule ligne de code

# %%
#LA REPONSE ICI

# %% [markdown]
# ## **Exercice 8 $(\star\star)$ :** Liste en compréhension
#
# On veut ajouter la valeur 3 à chaque élément d’une liste d’entiers de 0 à 5 et stocker le résultat dans une nouvelle liste. Pour cela, on utilisera soit une boucle `for` simple, soit une liste en compréhension.
#
# Même question pour multiplier chaque élément par 10.

# %%
#LA REPONSE ICI

# %% [markdown]
# ## **Exercice 9 $(\star\star)$ :** Fonctions mathématiques et listes
# Pour accéder aux fonctions factorielle ou exponentielle, on utilisera `factorial(x)` et `exp(x)` des modules `numpy` et `scipy` de Python. Pour cela, on pourra utiliser la commande:
# ```python
# from numpy import exp
# from scipy.special import factorial
# ```
#
# 1. Créer une liste des entiers compris entre 0 et 9.
# 2. Construire trois nouvelles listes associées aux valeurs de $x!$, $x^2$ et $\exp(x)$.
# 3. Afficher les résultats, on pourra utiliser la fonction `round()` pour améliorer la présentation.
# 4. Pour des grands nombres, quelle est la fonction qui croît le plus rapidement  ?

# %%
#LA REPONSE ICI

# %% [markdown]
# ## **Exercice 10 $(\star\star)$ :** Listes en compréhension avec des tests
#
# 1. Écrire un programme qui, à partir d'une liste `inlist` d'entiers, crée une liste extraite `listpair` qui ne garde que les éléments pairs de `inlist`.
#
# 2. Écrire un programme qui modifie `inlist` en supprimant tous ses éléments pairs.
#
# On pourra soit utiliser une boucle `for`, soit utiliser des listes en compréhension.
#
# 3. On part d'une liste d'entiers de 2 à 8. Utiliser une liste en compréhension pour multiplier par 3 chaque élément d’une liste d’entiers de 0 à 5 mais en ne considérant que les éléments de la liste qui sont supérieurs ou égaux à 6.

# %%
#LA REPONSE ICI

# %% [markdown]
# ## **Exercice 11 $(\star\!\star\!\star)$ :**  Premier cryptage
#
# Écrire un programme qui :
# 1. initialise une variable chaîne de caractères avec un texte que vous voulez crypter ;
#
# **Remarque :** Pour se simplifier la vie, si la chaîne de caractères a une longueur impaire, on pourra ajouter une espace en fin de chaîne de caractères.
#
# 2. crée une première chaîne de caractères avec les caractères du texte en position paire ;
# 3. crée une deuxième chaîne de caractères avec les caractères du texte en position impaire ;
# 4. crée une variable qui concatène ces deux listes et l'affiche ;
# 5. Écrire un programme qui permet de décrypter la chaîne résultante (i.e qui effectue le processus permettant de revenir au texte initial).

# %%
#LA REPONSE ICI

# %% [markdown]
# ## **Exercice 12 $(\star\!\star\!\star)$ :**  Chiffre de César
#
# Le chiffrement par décalage, aussi connu comme le chiffre ou le code de César, consiste à remplacer une lettre par une lettre située $n$ lettres plus loin dans l'alphabet. Pour simplifier les choses, on supposera que la chaîne de caractères
# - s'écrit en minuscule
# - ne comporte pas de caractères spéciaux autres que l'espace et aucun caractère accentué.
#
# 1. Écrire un programme qui déclare un décalage `Nshift` et crypte une chaîne de caractères via l'opération décrite précédemment.
# 2. Écrire ensuite le programme permettant d'effectuer le décryptage.

# %%
alphabet = 'abcdefghijklmnopqrstuvwxyz ' # on inclut l'espace
#LA REPONSE ICI

# %% [markdown]
# ## **Exercice 13 $(\star\!\star\!\star)$ :**  Pangramme
#
# Un pangramme est une phrase comportant toutes les lettres de l'alphabet. *Portez ce vieux whisky au juge blond qui fume* est probablement l'exemple le plus connu en français (en outre c'est un alexandrin !).
#
# Écrire un programme vérifiant si une chaîne de caractères (sans caractère accentué) est un pangramme. Au besoin, on pourra récupérer la chaîne de caractères en minuscule à l'aide de la méthode `.lower()`.

# %%
#LA REPONSE ICI
