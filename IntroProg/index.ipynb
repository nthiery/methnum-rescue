# %% [markdown]
# # Introduction à la programmation, avec Python et Jupyter

# %% [markdown]
# :::{admonition} À propos de ce devoir
# :class: hint dropdown
#
# Les séances 1 à 5 du cours de L1 de Méthodes Numériques (MethNum) sont
# dédiées à l'apprentissage des bases de la programmation. Le matériel
# pédagogique est usuellement fourni sous la forme de cinq devoirs
# `Seance1`, ..., `Seance5`. Alternativement, vous pouvez utiliser en
# avance de phase le matériel pédagogique proposé ici, basé sur un
# [cours
# mutualisé](https://py-edu-fr.pages.heptapod.net/py-edu-fr/intro-prog/)
# que nous construisons dans le cadre du [Groupe de travail Python du
# CNRS](https://python-cnrs.netlify.app/) et qui remplacera MethNum L1
# en 2026-2027.
#
# :::

# %% [markdown]
# ## Parcours Pédagogique

# %% [markdown]
# :::{admonition} Note
# :class: hint
#
# Un parcours pédagogique pour les séances 1 à 5 vous est proposé
# ci-dessous. Vous trouverez à quel rythme avancer dans ce parcours
# [sur la page eCampus du cours](https://ecampus.paris-saclay.fr/course/section.php?id=637009).
#
# Vous pouvez adapter ce parcours pédagogique en fonction de votre expérience.
# Vous pouvez aussi explorer la table des matières, où les feuilles sont classées par
# thème. Vous noterez que le parcours proposé tourne parmi les thèmes en revenant dessus
# tour à tour pour les approfondir (apprentissage en spirale).
# :::

# %% [markdown]
# ### [Présentation de l'UE](methnum.ipynb)

# %% [markdown]
# ### 0 - Découvrir Jupyter

# %% [markdown]
# Dans ce cours, vous utiliserez des *feuilles d'exercices interactives `Jupyter`*.
# `Jupyter` est une application web qui permet de programmer interactivement dans de
# nombreux langages (`Python`, `C++`, ...), un peu comme une super calculatrice, et de
# rédiger des documents interactifs.
#
# :::{admonition} Indication
# :class: tip
#
# Si vous êtes déjà familier avec l'utilisation de Jupyter, vous pouvez passer directement
# à la suite.
# :::
#
# 1. Ouvrez la feuille de travail
#    [Prise en main de Jupyter](jupyter/prise-en-main.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=jupyter/prise-en-main.ipynb) -->
#
# 2. Suivez les instructions qu'elle contient.

# %% [markdown]
# ### 1 - Découvrir Python

# %% [markdown]
# :::{figure} premiers-pas/media/laby3a.png
#
# :::
#
# Le jeu Laby propose plusieurs défis successifs; pour chacun d'entre eux, le but est de
# guider pas-à-pas une fourmi vers la sortie d'un labyrinthe à l'aide d'un programme.
# Chacun de ces défis sera l'occasion d'avoir un premier contact ludique avec quelques
# concepts (programme, conditionnelles, boucles, fonctions) que nous approfondirons par la
# suite.
#
# :::{admonition} En savoir plus sur Laby
# :class: seealso, dropdown
#
# Le jeu [Laby](https://sgimenez.github.io/laby/) a été originellement créé par Stéphane
# Gimenez et collaborateurs pour la Fête de la Science à Jussieu. Nous utiliserons ici une
# [réimplantation de Laby pour Python, dans Jupyter](https://gitlab.dsi.universite-paris-saclay.fr/nicolas.thiery/Laby.git).
# :::

# %% [markdown]
# Chaque feuille ci-dessous correspond à un défi. Ouvrez-les tour à tour dans l'ordre et
# suivez les instructions incluses. Si vous bloquez sur l'un des défis, n'hésitez pas à
# passer à la suite et à y revenir ultérieurement.
#
# % Vous pouvez cocher les cases ci-dessous au fur et à mesure que vous finissez les feuilles.
#
# % Déposez votre travail après chaque fiche.
#
# - [Prise en main de Laby](premiers-pas/01-prise-en-main-laby.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/01-prise-en-main-laby.ipynb) -->
# - [À vous de jouer](premiers-pas/10-premier-exo.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/10-premier-exo.ipynb) -->
# - [Un caillou dans la chaussure](premiers-pas/11-un-caillou.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/11-un-caillou.ipynb) -->
# - [Encore un caillou!](premiers-pas/12-encore-un-caillou.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/12-encore-un-caillou.ipynb) -->
# - [Le débogueur](premiers-pas/13-pas-a-pas.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/13-pas-a-pas.ipynb) -->
#
# Répéter :
#
# % boucles while
#
# - [Que c'est loin!](premiers-pas/20-on-regarde-devant-soi.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/20-on-regarde-devant-soi.ipynb) -->
# - [Le couloir des cailloux](premiers-pas/21-beaucoup-de-cailloux.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/21-beaucoup-de-cailloux.ipynb) -->
#
# % et petites fonctions
#
# - [En zigzag](premiers-pas/22-en-zigzag.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/22-en-zigzag.ipynb) -->
# - [La spirale infernale](premiers-pas/23-la-spirale.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/23-la-spirale.ipynb) -->
#
# %- ♣ [Encore un zigzag](premiers-pas/24-encore-un-zigzag.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/24-encore-un-zigzag.ipynb) -->
#
# S'adapter :
#
# % conditionnelles
#
# - [Ahhh des toiles!](premiers-pas/30-si-si-si.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/30-si-si-si.ipynb) -->
#
# %- [Le caillou et la toile](premiers-pas/31-le-caillou-et-la-toile.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/31-le-caillou-et-la-toile.ipynb) -->
#
# Compter :
#
# % boucles for et variables
#
# - [Tu répéteras trois fois](boucles/02-boucles-for-introduction-laby.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=boucles/02-boucles-for-introduction-laby.ipynb) -->
# - [Variables](premiers-pas/41-variables.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/41-variables.ipynb) -->
# - [Compter les cailloux](premiers-pas/42-compter.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/42-compter.ipynb) -->

# %% [markdown]
# ### 2 - Calculer

# %% [markdown]
# - [Jupyter: mode édition versus mode commande](jupyter/mode-edition-vs-commande.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=jupyter/mode-edition-vs-commande.ipynb) -->
# - [Valeurs et types](premiers-calculs/01-valeurs-types.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-calculs/01-valeurs-types.ipynb) -->
# - [Fonctions mathématiques](premiers-calculs/02-fonctions-maths.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-calculs/02-fonctions-maths.ipynb) -->
# - [Prendre des notes](prendre-des-notes.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=prendre-des-notes.ipynb) -->
# - [Variables](premiers-calculs/03-variables.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-calculs/03-variables.ipynb) -->
# - [Premières fonctions](fonctions/00-initiation-fonctions.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=fonctions/00-initiation-fonctions.ipynb) -->

# %% [markdown]
# ### 3 - S'adapter au contexte : les instructions conditionnelles

# %% [markdown]
# - [Jupyter: le noyau](jupyter/le-noyau.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=jupyter/le-noyau.ipynb) -->
# - [Conditions](conditions/01-conditions.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=conditions/01-conditions.ipynb) -->
# - [Laby : Le caillou et la toile](premiers-pas/31-le-caillou-et-la-toile.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/31-le-caillou-et-la-toile.ipynb) -->

# %% [markdown]
# (repeter)=
# ### 4 - Répéter : les instructions itératives (boucles)

# %% [markdown]
# :::{attention}
# Les défis marqués d'un ♣ ou ♣♣ sont (nettement) plus avancés; sauf si vous êtes à l'aise
# et recherchez un peu de défi, nous vous recommandons de les sauter et de revenir dessus
# ultérieurement lorsque vous aurez vu plus formellement les concepts sous-jacents.
# :::
#
# - [Jupyter: les types de cellules](jupyter/les-types-de-cellules.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=jupyter/les-types-de-cellules.ipynb) -->
# - [Affichages](entrees-sorties/05-affichages.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=entrees-sorties/05-affichages.ipynb) -->
# - [Boucles while](boucles/01-boucles-while.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=boucles/01-boucles-while.ipynb) -->
# - ♣ [Laby : Encore un zigzag](premiers-pas/24-encore-un-zigzag.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/24-encore-un-zigzag.ipynb) -->
# - ♣ [Laby : Un labyrinthe aléatoire](premiers-pas/52-labyrinthes-aleatoires.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/52-labyrinthes-aleatoires.ipynb) -->
# - ♣ [Par où passer?](premiers-pas/50-les-toiles.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/50-les-toiles.ipynb) -->
# - ♣ [Toiles et cailloux](premiers-pas/51-toiles-et-cailloux.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/51-toiles-et-cailloux.ipynb) -->
# - [Boucles for](boucles/02-boucles-for.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=boucles/02-boucles-for.ipynb) -->
# - [Débogueur](entrees-sorties/02-debogueur.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=entrees-sorties/02-debogueur.ipynb) -->
# - [Compteurs et accumulateurs](boucles/03-compteurs-accumulateurs.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=boucles/03-compteurs-accumulateurs.ipynb) -->
# - ♣ [Doubles boucles for](boucles/04-dessins-geometriques.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=boucles/04-dessins-geometriques.ipynb) -->

# %% [markdown]
# (structurer)=
# ### 5 - Structurer un programme : les fonctions

# %% [markdown]
# - [L'interface de JupyterLab](jupyter/interface.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=jupyter/interface.ipynb) -->
# - [Fonctions](fonctions/01-fonctions.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=fonctions/01-fonctions.ipynb) -->
#
# Les deux séries d'exercices suivantes ont le même objectif
# pédagogique : résoudre un problème plus complexe par composition de
# petites fonctions. Vous pouvez choisir celle que vous préférez,
# sachant que la première (fonction exponentielle) a un peu plus de
# prérequis mathématiques.
#
# Calculer la fonction exponnentielle:
# - [Partie 1](fonctions/02-exponentielle1.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=fonctions/02-exponentielle1.ipynb) -->
# - [Partie 2](fonctions/02-exponentielle2.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=fonctions/02-exponentielle2.ipynb) -->
# - [Partie 3](fonctions/02-exponentielle3.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=fonctions/02-exponentielle3.ipynb) -->
# - ♣ [Partie 4](fonctions/02-exponentielle4.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=fonctions/02-exponentielle4.ipynb) -->
# - ♣ [Partie 5](fonctions/02-exponentielle5.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=fonctions/02-exponentielle5.ipynb) -->
#
# Implanter un moteur simple de censure de texte:
# - [Partie 1](fonctions/03-censure-texte1.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=fonctions/03-censure-texte1.ipynb) -->
# - [Partie 2](fonctions/03-censure-texte2.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=fonctions/03-censure-texte2.ipynb) -->
# - [Partie 3](fonctions/03-censure-texte3.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=fonctions/03-censure-texte3.ipynb) -->
# - [Partie 4](fonctions/03-censure-texte4.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=fonctions/03-censure-texte4.ipynb) -->

# %% [markdown]
# ### 6 - Structurer les données

# %% [markdown]
# - [Jupyter: jeter sa souris](jupyter/jeter-sa-souris.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=jupyter/jeter-sa-souris.ipynb) -->
# - [Les listes](donnees/01-listes.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=donnees/01-listes.ipynb) -->
# - [Parcours de listes](donnees/02-parcours.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=donnees/02-parcours.ipynb) -->
# - [Compréhensions de listes](donnees/03-comprehensions.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=donnees/03-comprehensions.ipynb) -->
# - [Tables de données (Pandas)](donnees/tables.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=donnees/tables.ipynb) -->
# - [Tableaux (Numpy)](donnees/tableaux.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=donnees/tableaux.ipynb) -->
#
# %- [Images (PIL)](donnees/images.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=donnees/images.ipynb) -->
#
# % ## Représenter les données

# %% [markdown]
# ### 7 - Communiquer : Entrées / sorties

# %% [markdown]
# ### 8 - Structurer un programme : les modules

# %% [markdown]
# - [Jupyter: l'indentation](jupyter/indentation.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=jupyter/indentation.ipynb) -->

# %% [markdown]
# ### 9 - Défis supplémentaires

# %% [markdown]
# % S'adapter à tout :
# % algorithmiques génériques
#
# - ♣♣ [Laby : Fabriquer votre labyrinthe](premiers-pas/54-fabriquer.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/54-fabriquer.ipynb) -->
# - ♣♣ [C'est fou!](premiers-pas/53-c-est-fou.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=premiers-pas/53-c-est-fou.ipynb) -->
#
# ### 10 - Mini projets
#
# - [Géométrie constructive des solides avec pyvista](projets/geometrie-constructive-3D.ipynb) <!-- ![ ](/jupylates/learning-object-status?id=projets/geometrie-constructive-3D.ipynb) -->
