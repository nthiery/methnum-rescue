# %% [markdown]
# :::{admonition} Objectifs pédagogiques
# Utiliser la boucle for et les conditionnelles
# :::

# %%
from random import randint
import math

# %% [markdown]
# :::{admonition} Consigne
#
# Écrire une fonction `est_premier` qui prend un entier `n` positif en paramètre, renvoie `True` s'il est premier et `False` sinon. Rappel : un nombre naturel n est dit premier s’il a exactement deux facteurs, 1 et le nombre lui-même (n). 2 est le plus petit entier premier.
#
# :::

# %%
### BEGIN SOLUTION
def est_premier(n) :
    if n==1:
        return False
    for i in range(2,n) :
        if (n%i) == 0 :
            return False
    return True
### END SOLUTION

# %%
assert est_premier(2), "est_premier(2) devrait renvoyer True"
assert not est_premier(1), "est_premier(1) devrait renvoyer False"
assert est_premier(7), "est_premier(7) devrait renvoyer True"
assert est_premier(3) , "est_premier(3) devrait renvoyer True"
assert not est_premier(16), "est_premier(16) devrait renvoyer TruFalsee"
assert est_premier(97), "est_premier(97) devrait renvoyer True"
