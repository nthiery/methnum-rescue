# %% [markdown]
# # Un caillou dans la chaussure
#
# Exécutez la cellule suivante pour faire apparaître le second défi. Cette fois il y a un
# obstacle: un caillou barre la route. Il faudra le prendre et le poser ailleurs.
#
# **Indication :** revenez à la feuille de [prise en main](01-prise-en-main-laby.ipynb) pour
# avoir un exemple et consulter la
# [documentation](01-prise-en-main-laby.md#documentation_laby).
#
# **Remarque :** la fourmi ne peut pas ouvrir la porte si elle porte un caillou.

# %%
from laby.global_fr import *
Laby(niveau="1b")

# %%
debut()
# REMPLACEZ TOUTE CETTE LIGNE PAR VOTRE CODE
ouvre()

# %%
assert est_gagnant()

# %% [markdown]
# |< Précédent|^ Remonter ^|Suivant >|
# |:---|:---:|---:|
# |[À vous de jouer!](10-premier-exo.ipynb)|[Introduction à la programmation, avec Python et Jupyter](../index.ipynb)|[Un caillou dans un couloir](12-encore-un-caillou.ipynb)|
