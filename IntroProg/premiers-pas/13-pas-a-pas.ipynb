# %% [markdown]
# # Pas à pas

# %% [markdown]
# (deboguer)=
# Cette fois, le défi est de ***déboguer*** un programme existant,
# c'est-à-dire d'identifier, analyser et corriger une erreur qui s'y cache. Ce sera
# l'occasion d'apprendre à **observer** l'**exécution pas à pas** d'un programme, pour bien
# comprendre son fonctionnement.

# %% [markdown]
# 1. Exécutez les deux cellules ci-dessous pour faire apparaître le labyrinthe et exécuter
#    le programme.

# %%
from laby.global_fr import *
Laby(niveau="1b")

# %%
debut()
avance()
droite()
avance()
prend()
avance()
droite()
pose()
gauche()
avance()
avance()
gauche()
avance()
droite()
ouvre()

# %% [markdown]
# Vous constaterez qu'à la fin la fourmi porte toujours son caillou et ne peux donc pas
# sortir.
#
# 2. Utilisez les boutons de commande du labyrinthe pour suivre l’exécution du programme
#    pas-à-pas, en marche avant et arrière, etc pour bien comprendre ce que fait la fourmi.

# %% [markdown]
# À ce stade, vous avez probablement déjà identifié le problème. Cependant il n'est pas
# évident de faire le lien entre chaque actions de la fourmi et la ligne du programme
# correspondante. Pour pallier cela, nous allons utiliser le **débogueur**.
#
# 3. Activez le débogueur en cliquant sur l'insecte
#    ([*bug*](https://www.caminteresse.fr/sciences/dou-vient-le-mot-bug-1174190/) en
#    anglais) à droite de la barre de contrôle en haut de cette page :
#
# :::{figure} media/debug1.png
#
# :::

# %% [markdown]
# L'insecte est devenu rouge, les numéros des lignes sont apparus à gauche dans les
# cellules de code, et une palette s'est ouverte à droite de cette feuille.
#
# Le débogueur permet de définir des **points d'arrêts** dans le code : l'exécution du
# programme est mise en pause chaque fois qu'elle atteint un point d'arrêt.
#
# 4. Ajoutez un point d'arrêt sur la deuxième ligne du programme en cliquant à gauche de la
#    ligne `avance()` :
#
# :::{figure} media/debug2.png
#
# :::

# %% [markdown]
# 5. Exécutez la cellule contenant le programme.
#
# % si vous l'aviez déjà exécutée, cliquez sur le bouton ![debug3.png](media/debug3.png) pour faire revenir la fourmi à son point de départ, puis exécutez-la à nouveau.

# %% [markdown]
# Vous remarquerez que la fourmi est en position de départ et que l'exécution est en cours
# (comme nous l'indique l'étoile entre crochets `[*]` à gauche de la cellule) : l'exécution
# est mise en pause sur la ligne du point d'arrêt, juste avant l'exécution de cette ligne.
#
# 6. Appuyez sur la touche <kbd>F10</kbd> (sur certains claviers:
#    <kbd>fn</kbd>+<kbd>F10</kbd>) pour avancer d'un pas jusqu'à l'instruction suivante.
#    Alternativement, vous pouvez cliquer sur la flèche dans la zone `PILE DES APPELS` de
#    la palette à droite.
#
# :::{figure} media/debug4.png
#
# :::

# %% [markdown]
# 7. Continuez à appuyer sur `F10` et observez l'exécution du programme pas à pas. Pour
#    relancer le programme depuis le début, exécutez à nouveau la cellule.
#
# 8. Analysez l'erreur et corrigez la. Relancez l'exécution pas à pas pour vérifier.
#
# 9. Cliquez sur l'insecte pour désactiver le débogueur.
#
# :::{hint}
# Si le débogueur a un comportement erratique (point d'arrêt ignoré, ...): cliquez deux
# fois sur l'insecte pour désactiver le débogueur puis reprenez en 3.
# :::

# %% [markdown]
# ## Conclusion
#
# Dans cette feuille, vous avez **exécuté pas-à-pas** un programme afin d'observer et
# comprendre précisément son fonctionnement. C'est une stratégie efficace à mettre en œuvre
# chaque fois que vous avez un doute pour prédire le comportement d'un programme, notamment
# pour [déboguer](#deboguer) des erreurs.
#
# Vous avez aussi découvert les commandes essentielles pour utiliser le **débogueur**.
# Disponible dans Jupyter et tout bon environnement de développement, c'est un outil de
# choix pour vous aider à mettre en œuvre cette stratégie.
#
# Au fur et à mesure que vous aborderez des programmes plus complexes, vous raffinerez vos
# stratégies d'observations et vous vous familiariserez avec la richesse des fonctionalités
# d'observation qu'offre le débogueur, notamment via la palette de droite dans Jupyter.

# %% [markdown]
# |< Précédent|^ Remonter ^|Suivant >|
# |:---|:---:|---:|
# |[Un caillou dans un couloir](12-encore-un-caillou.ipynb)|[Introduction à la programmation, avec Python et Jupyter](../index.ipynb)|[On regarde devant soi](20-on-regarde-devant-soi.ipynb)|
